# %% [markdown]
# ### CRIV4
# Analise Fundamentalista

# %%
from matplotlib import pyplot as plt

# %%
VMercado = 741_190_000.000
VPatrimonial = 942_527_000.000
NroAçoes = 102_943_000.000
V_VP = VMercado / VPatrimonial

Data = [["VMercado", "VPatrimonial", "NroAçoes"], [VMercado, VPatrimonial, NroAçoes]]

# %%
plt.bar(Data[0], Data[1], color=['Red', 'Blue', 'Green'])
# Out:
# <BarContainer object of 3 artists>

# %%
V_VP
# Out:
# 0.7863859602960976
