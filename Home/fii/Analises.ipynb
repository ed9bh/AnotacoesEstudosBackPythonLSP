# %% [markdown]
# #### Análises Baseadas em Dados Baixados (FII)

# %%
from os import chdir, listdir
from glob import glob
import pandas as pd
from matplotlib import pyplot as plt

# %%
chdir('logFiles')
csv_files = glob('*.csv')

# %%
Report_File_Log = pd.read_csv('Report.txt', sep='\t', names=['Ticker', 'Aluguel', 'Adj Close'])

# %%
Report_File_Log.head()
# Out:
#    Ticker Aluguel   Adj Close
# 0  ALZR11  0.4820  105.500000
# 1  AQLL11       -  470.000000
# 2  BCRI11  0.8300  132.800003
# 3  BNFS11  0.7669  129.300003
# 4  BBPO11  1.0579  150.199997

# %%
Report_File_Log.tail()
# Out:
#      Ticker Aluguel    Adj Close
# 140  XPHT11  0.6000   105.449997
# 141  XPIN11  0.7200   113.980003
# 142  XPLG11  0.6100   106.290001
# 143  XPML11  0.5700   111.779999
# 144  YCHY11       -  1000.000000

# %%
plt.style.use('seaborn')

# %%
plt.plot(Report_File_Log['Adj Close'])
plt.plot(Report_File_Log['Aluguel'])

# %%
x = [x for x in range(len(Report_File_Log['Aluguel'][0:10]))]
plt.bar(x, height=Report_File_Log['Aluguel'][0:10])
labels = array(Report_File_Log['Ticker'][0:10].item)
plt.xlabel(labels)
# Out:
# Text(0.5, 0, '<bound method IndexOpsMixin.item of 0    ALZR11\n1    AQLL11\n2    BCRI11\n3    BNFS11\n4    BBPO11\n5    BBRC11\n6    RDPD11\n7    RNDP11\n8    BCIA11\n9    BZLI11\nName: Ticker, dtype: object>')
