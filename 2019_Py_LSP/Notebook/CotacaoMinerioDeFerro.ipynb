# %% [markdown]
# # Modulo QUANDL
# ## Descobrir Preço Insumos
# ### Cotação Minério de Ferro // Petroleo
#
# https://www.quandl.com/data/ODA/PIORECR_USD-Iron-Ore-Price
#
# https://www.google.com/search?newwindow=1&ei=od9BXIi0B9XC5OUPzrSruAU&q=python+quandl+iron+ore&oq=python+quandl+iron+ore&gs_l=psy-ab.3...300215.301731..301917...0.0..0.174.1129.0j8......0....1..gws-wiz.......0i71j35i39j0i203j0i22i30j33i160j33i22i29i30.-l6yWjv9nI4

# %%
import quandl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# mydata_IronOre = quandl.get("ODA/PIORECR_USD-Iron-Ore-Price") # start_date="2019-01-01", end_date="2019-01-18"
# mydata_IronOre = quandl.get('CHRIS/CME_TIO1-Iron-Ore-62-Fe-CFR-China-TSI-Futures-Continuous-Contract-1-TIO1-Front-Month')
mydata_IronOre = quandl.get('CHRIS/SGX_FEF1-Iron-Ore-Futures-Continuous-Contract-1-FEF1-Front-Month')

# %%
mydata_IronOre.head()
# Out:
#               Open    High     Low   Close  Settle  Volume  \
# Date
# 2013-10-01  129.75  129.75  129.75  129.75  129.75     0.0
# 2013-10-02  128.81  128.81  128.81  128.81  128.81     0.0
# 2013-10-03  129.25  129.25  129.25  129.25  129.25     0.0
# 2013-10-04  129.37  129.37  129.37  129.37  129.37     0.0
# 2013-10-07  129.58  129.58  129.58  129.58  129.58     0.0
#
#             Prev. Day Open Interest
# Date
# 2013-10-01                    383.0
# 2013-10-02                    383.0
# 2013-10-03                    383.0
# 2013-10-04                    383.0
# 2013-10-07                    383.0

# %%
mydata_IronOre.tail()
# Out:
#              Open   High    Low  Close  Settle  Volume  \
# Date
# 2019-01-04  72.50  73.20  72.50  73.20   72.95  8273.0
# 2019-01-07  73.20  74.30  73.10  74.30   74.32  7966.0
# 2019-01-08  74.20  74.60  73.95  74.60   74.55  6199.0
# 2019-01-09  74.64  74.75  74.11  74.18   74.22  6008.0
# 2019-01-10  73.71  74.10  73.55  74.10   74.05  5871.0
#
#             Prev. Day Open Interest
# Date
# 2019-01-04                 122098.0
# 2019-01-07                 122547.0
# 2019-01-08                 123512.0
# 2019-01-09                 122839.0
# 2019-01-10                 121990.0

# %%
mydata_IronOre['Close'].plot()

# %%
mydata_Pet = quandl.get("EIA/PET_RWTC_D")

# %%
mydata_Pet.head()
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87

# %%
mydata_Pet.tail()
# Out:
#             Value
# Date
# 2019-01-22  52.59
# 2019-01-23  52.44
# 2019-01-24  52.94
# 2019-01-25  53.53
# 2019-01-28  51.79

# %%
mydata_Pet.plot()

# %%
mydata_IronOre_Pet = quandl.get(['CHRIS/SGX_FEF1-Iron-Ore-Futures-Continuous-Contract-1-FEF1-Front-Month', 'EIA/PET_RWTC_D'])

# %%
mydata_IronOre_Pet.plot()
