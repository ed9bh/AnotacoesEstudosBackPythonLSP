# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import linregress
plt.style.use('bmh')

# %%
x, y = [], []

# %%
for c in range(100):
    x.append(c)
    y.append(np.random.randint(9,999))
    pass

x = np.array(x)
y = np.array(y)

# %%
p1 = np.polyfit(x, y, 1)
poly_1 = np.polyval(p1, x)

p2 = np.polyfit(x, y, 12)
poly_2 = np.polyval(p2, x)

p3 = np.polyfit(x, y, np.floor(len(x) * 0.15))
poly_3 = np.polyval(p3, x)

p1, p2, p3
# Out:
# (array([-3.11605161e-01,  5.45534455e+02]),
#  array([ 2.15363219e-17,  8.33725734e-15, -7.64541658e-12,  1.95045058e-09,
#         -2.59276283e-07,  2.06349812e-05, -1.02677574e-03,  3.18940893e-02,
#         -5.96557967e-01,  6.27560662e+00, -3.48484884e+01,  1.20097391e+02,
#          2.53173645e+02]),
#  array([-4.04299811e-20,  3.04443219e-17, -1.03675116e-14,  2.11086043e-12,
#         -2.86177446e-10,  2.72243181e-08, -1.86510085e-06,  9.29144334e-05,
#         -3.35652466e-03,  8.66557039e-02, -1.55474988e+00,  1.85136232e+01,
#         -1.35712081e+02,  5.34519459e+02, -8.13255158e+02,  4.90031922e+02]))

# %%
plt.figure(figsize=(18,6))
plt.plot(x, y)
plt.plot(x, poly_1)

plt.tight_layout()

# %%
plt.figure(figsize=(18,6))
plt.plot(x, y)
plt.plot(x, poly_2)

plt.tight_layout()

# %%
plt.figure(figsize=(18,6))
plt.plot(x, y)
plt.plot(x, poly_3)

plt.tight_layout()

# %%
slope, intercept, rvalue, pvalue, stderr = linregress(x,y)

print(f'{slope}, {intercept}, {rvalue}, {pvalue}, {stderr}')
# Out:
# -0.3116051605160518, 545.5344554455446, -0.031124849293564336, 0.7585314559585141, 1.0108201289132166
